# %% [markdown]
# MODULE 1: INTRODUCTION TO DATA ANALYTICS

# %% [raw]
# 1.1.What is Data and Types of Data
# 1.2.What, why and how of data analytics
# 1.3.Role of analytical thinking & problem solving
# 1.4.Components of Data Analytics
# 1.5.Data Analysis techniques (Descriptive, Predictive etc)
# 1.6.Popular Data analysis tools

# %% [markdown]
# 1.1 What is Data and Types of Data

# %% [raw]
# Data is a collection of raw facts, figures, measurements, or observations that can be processed to generate meaningful information.
# Data by itself has no meaning until it is analyzed.

# %% [raw]
# Types of Data

# %% [raw]
# Qualitative Data (Categorical Data)
# Nominal Data : Categories without order.
#
# Example:
# Blood group
# Color
# City
#
# Ordinal Data : Categories with ranking.(order)
#
# Example:
# Customer satisfaction:
# Poor < Average < Good < Excellent

# %% [raw]
# Quantitative Data (Numerical Data)

# %% [raw]
# Discrete Data : Countable numbers.
#
# Examples:
#
# Number of students
# Number of cars
# Number of orders
#
# Continuous Data : Measurable values that can have decimals.
#
# Examples:
#
# Height
# Temperature
# Weight
# Time

# %% [raw]
# Structured Data : Highly organized data stored in tables or databases.
#
# Example:
# SQL tables, Excel sheets

# %% [raw]
# Unstructured Data : Data without predefined structure.
#
# Examples:
# Images
# Videos
# Emails
# Social media posts

# %% [raw]
# Semi-Structured Data : Partially organized data.
#
# Examples:
# JSON
# XML
# Log files

# %% [markdown]
# 1.2 What, why and how of data analytics

# %% [raw]
# What is Data Analytics?
#
# Data Analytics is the process of collecting, cleaning, analyzing, and interpreting data to extract useful insights and support decision-making.

# %% [raw]
# Why Data Analytics is Important
# Organizations use data analytics to:
#
# 1 Improve Decision Making
#
# 2 Understand Customer Behavior
#
# 3 Increase Business Efficiency
#
# 4 Predict Future Trends

# %% [raw]
# How Data Analytics Works (Process)
#
# Data analytics follows a step-by-step workflow.
#
# Step 1: Data Collection - Data is collected from:
#
# Step 2: Data Cleaning - Remove: missing values,duplicates,incorrect data
#
# Step 3: Data Processing - Data is organized into structured format.
#
# Step 4: Data Analysis - Using statistical and analytical methods to identify patterns.
#
# Step 5: Data Visualization - Present results using:charts,graphs,dashboards
#
# Step 6: Decision Making - Businesses use insights to make strategic decisions.

# %% [markdown]
# 1.3 Role of Analytical Thinking and Problem Solving

# %%
Analytical thinking is the ability to break down complex problems into smaller parts and analyze them logically.

# %% [raw]
# Example
#
# Problem:
#
# Sales dropped last month.
#
# Analytical thinking approach:
#
# 1 Identify the problem
# 2 Collect relevant data
# 3 Analyze trends
# 4 Identify causes
# 5 Suggest solutions
#
# Possible reasons:
#
# price increase
# competitor discount
# seasonal demand

# %% [raw]
# Problem Solving in Data Analytics - Data analysts solve problems using a structured approach.
#
# Steps
#
# 1 Define the problem
# 2 Collect relevant data
# 3 Analyze the data
# 4 Identify insights
# 5 Recommend actions

# %% [markdown]
# 1.4 Components of Data Analytics

# %% [raw]
# 1 Data Collection : Gathering data from various sources.
# 2 Data Storage : storing data in systems like:
# 3 Data Processing : Transforming raw data into structured form.
# 4 Data Analysis : Applying techniques to extract insights.
# 5 Data Visualization : Representing results visually.
# 6 Data Interpretation : Understanding results and communicating findings to stakeholders.

# %% [markdown]
# 1.5 Data Analysis Techniques

# %% [raw]
# 1 Descriptive Analytics : What happened?
# Techniques:
# averages
# totals
# percentages
#
# 2 Diagnostic Analytics : Why did it happen?
# Techniques:
# drill-down analysis
# correlation analysis
# root cause analysis.
#
# 3 Predictive Analytics : What will happen in the future?
# Techniques:
# regression
# classification
# time series forecasting.
#
# 4 Prescriptive Analytics : What should we do?
# Techniques:
#
# optimization
# simulation
# AI models.

# %% [markdown]
# 1.6 Popular Data Analysis Tools

# %%
1 Excel : Most widely used tool for beginners.
2 SQL : Used to query databases.
3 Python : Popular programming language for data analysis.
Libraries: Pandas, NumPy, Matplotlib, Seaborn
4 Power BI : Business intelligence tool for interactive dashboards.
5 Tableau : Advanced data visualization tool.
6 R Programming : Statistical programming language.
